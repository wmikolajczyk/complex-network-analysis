# %%
# Generative graphs
import networkx as nx

from collections import defaultdict

from graph import generate_graph, attach_graph_attributes, get_graph_measurements, compare_graph_measurements, print_comparison_results
from recreate_graph import graph_to_dataframe, get_trained_model, recreate_by_priority_rank
# Out:
# Using TensorFlow backend.
# /home/smoq/.virtualenvs/cna/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
graph_families = [
    {
        'name': 'erdos renyi',
        'func': nx.erdos_renyi_graph,
        'params': [
            {'n': 30, 'p': 0.05},
            {'n': 30, 'p': 0.1},
            {'n': 30, 'p': 0.3}
        ]
    },
    {
        'name': 'watts strogatz',
        'func': nx.watts_strogatz_graph,
        'params': [
            {'n': 30, 'k': 2, 'p': 0.05},
            {'n': 30, 'k': 2, 'p': 0.1},
            {'n': 30, 'k': 2, 'p': 0.3}
        ]
    },
    {
        'name': 'barabasi albert',
        'func': nx.barabasi_albert_graph,
        'params': [
            {'n': 30, 'm': 1},
            {'n': 30, 'm': 2},
            {'n': 30, 'm': 5}
        ]
    },
]

# %%
results = defaultdict(list)
for graph_family in graph_families:
    for params in graph_family['params']:
        graph = generate_graph(graph_family['func'], params)
        attach_graph_attributes(graph)

        df = graph_to_dataframe(graph)
        model = get_trained_model(df)

        new_graph = recreate_by_priority_rank(graph, df, model)

        graph_measurements = get_graph_measurements(graph)
        new_graph_measurements = get_graph_measurements(new_graph)

        comparison = compare_graph_measurements(graph_measurements, new_graph_measurements)
        results[graph_family['name']].append(comparison)
# Out:
# Epoch 1/4
# 900/900 [==============================] - 0s 64us/step - loss: 0.5602
# Epoch 2/4
#  64/900 [=>............................] - ETA: 0s - loss: 0.1484
# /home/smoq/projects/complex-network-analysis/recreate_graph.py:102: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.
#   df = df.reindex_axis(sorted(df.columns), axis=1)
# 900/900 [==============================] - 0s 14us/step - loss: 0.2377
# Epoch 3/4
# 900/900 [==============================] - 0s 16us/step - loss: 0.2404
# Epoch 4/4
# 900/900 [==============================] - 0s 14us/step - loss: 14.9150
# Cannot compute average_shortest_path_length - Graph is not connected.
# Cannot compute diameter - Found infinite path length because the graph is not connected
# Epoch 1/4
# 900/900 [==============================] - 0s 59us/step - loss: 0.6114
# Epoch 2/4
# 900/900 [==============================] - 0s 13us/step - loss: 0.3342
# Epoch 3/4
# 900/900 [==============================] - 0s 18us/step - loss: 0.3353
# Epoch 4/4
# 900/900 [==============================] - 0s 13us/step - loss: 0.3332
# Epoch 1/4
# 900/900 [==============================] - 0s 65us/step - loss: 0.7703
# Epoch 2/4
# 900/900 [==============================] - 0s 14us/step - loss: 0.6210
# Epoch 3/4
# 900/900 [==============================] - 0s 15us/step - loss: 0.6206
# Epoch 4/4
# 900/900 [==============================] - 0s 16us/step - loss: 0.6189
# Epoch 1/4
# 900/900 [==============================] - 0s 81us/step - loss: 0.5722
# Epoch 2/4
# 900/900 [==============================] - 0s 12us/step - loss: 0.2521
# Epoch 3/4
# 900/900 [==============================] - 0s 12us/step - loss: 0.2509
# Epoch 4/4
# 900/900 [==============================] - 0s 15us/step - loss: 0.2566
# Cannot compute average_shortest_path_length - Graph is not connected.
# Cannot compute diameter - Found infinite path length because the graph is not connected
# Epoch 1/4
# 900/900 [==============================] - 0s 106us/step - loss: 0.5735
# Epoch 2/4
# 900/900 [==============================] - 0s 14us/step - loss: 0.2672
# Epoch 3/4
# 900/900 [==============================] - 0s 14us/step - loss: 0.2520
# Epoch 4/4
# 900/900 [==============================] - 0s 20us/step - loss: 0.2501
# Cannot compute average_shortest_path_length - Graph is not connected.
# Cannot compute diameter - Found infinite path length because the graph is not connected
# Epoch 1/4
# 900/900 [==============================] - 0s 138us/step - loss: 0.5592
# Epoch 2/4
# 900/900 [==============================] - 0s 14us/step - loss: 0.2639
# Epoch 3/4
# 900/900 [==============================] - 0s 17us/step - loss: 0.2523
# Epoch 4/4
# 900/900 [==============================] - 0s 28us/step - loss: 0.2551
# Cannot compute average_shortest_path_length - Graph is not connected.
# Cannot compute diameter - Found infinite path length because the graph is not connected
# Epoch 1/4
# 900/900 [==============================] - 0s 134us/step - loss: 0.5996
# Epoch 2/4
# 900/900 [==============================] - 0s 16us/step - loss: 0.3792
# Epoch 3/4
# 900/900 [==============================] - 0s 18us/step - loss: 0.3875
# Epoch 4/4
# 900/900 [==============================] - 0s 28us/step - loss: 0.3311
# Epoch 1/4
# 900/900 [==============================] - 0s 156us/step - loss: 0.6559
# Epoch 2/4
# 900/900 [==============================] - 0s 18us/step - loss: 0.3613
# Epoch 3/4
# 900/900 [==============================] - 0s 12us/step - loss: 0.3552
# Epoch 4/4
# 900/900 [==============================] - 0s 23us/step - loss: 0.3468
# Epoch 1/4
# 900/900 [==============================] - 0s 124us/step - loss: 0.7606
# Epoch 2/4
# 900/900 [==============================] - 0s 16us/step - loss: 0.5843
# Epoch 3/4
# 900/900 [==============================] - 0s 14us/step - loss: 0.5768
# Epoch 4/4
# 900/900 [==============================] - 0s 17us/step - loss: 0.5750

# %%
for key, value in results.items():
    print(key)
    for i, comparison_result in enumerate(value):
        print('graph #{}'.format(i+1))
        print_comparison_results(comparison_result)
        print()
# Out:
# erdos renyi
# graph #1
# (KS test p-value)  degree_centrality: 0.99696924              [passed: True]
# (KS test p-value)  closeness_centrality: 0.20032515           [passed: True]
# (KS test p-value)  betweenness_centrality: 0.34203418         [passed: True]
# (KS test p-value)  pagerank: 0.93600859                       [passed: True]
# (abs distance)     average_shortest_path_length: None         [passed: None]
# (abs distance)     diameter: None                             [passed: None]
# (abs distance)     degree_centralization: 0.39751553          [passed: False]
# (abs distance)     density: 0.03448276                        [passed: True]
#
# graph #2
# (KS test p-value)  degree_centrality: 0.93600859              [passed: True]
# (KS test p-value)  closeness_centrality: 0.05499302           [passed: True]
# (KS test p-value)  betweenness_centrality: 0.53719954         [passed: True]
# (KS test p-value)  pagerank: 0.53719954                       [passed: True]
# (abs distance)     average_shortest_path_length: 0.10241935   [passed: False]
# (abs distance)     diameter: 0.16666667                       [passed: False]
# (abs distance)     degree_centralization: 0.26245847          [passed: False]
# (abs distance)     density: 0.25531915                        [passed: False]
#
# graph #3
# (KS test p-value)  degree_centrality: 0.20032515              [passed: True]
# (KS test p-value)  closeness_centrality: 0.05499302           [passed: True]
# (KS test p-value)  betweenness_centrality: 0.01131365         [passed: False]
# (KS test p-value)  pagerank: 0.10883839                       [passed: True]
# (abs distance)     average_shortest_path_length: 0.00813008   [passed: True]
# (abs distance)     diameter: 0.00000000                       [passed: True]
# (abs distance)     degree_centralization: 0.47145329          [passed: False]
# (abs distance)     density: 0.00704225                        [passed: True]
#
# watts strogatz
# graph #1
# (KS test p-value)  degree_centrality: 0.00061578              [passed: False]
# (KS test p-value)  closeness_centrality: 0.01131365           [passed: False]
# (KS test p-value)  betweenness_centrality: 0.00000000         [passed: False]
# (KS test p-value)  pagerank: 0.00020212                       [passed: False]
# (abs distance)     average_shortest_path_length: None         [passed: None]
# (abs distance)     diameter: None                             [passed: None]
# (abs distance)     degree_centralization: 0.73333333          [passed: False]
# (abs distance)     density: 0.03333333                        [passed: True]
#
# graph #2
# (KS test p-value)  degree_centrality: 0.00174595              [passed: False]
# (KS test p-value)  closeness_centrality: 0.10883839           [passed: True]
# (KS test p-value)  betweenness_centrality: 0.00000000         [passed: False]
# (KS test p-value)  pagerank: 0.00174595                       [passed: False]
# (abs distance)     average_shortest_path_length: None         [passed: None]
# (abs distance)     diameter: None                             [passed: None]
# (abs distance)     degree_centralization: 0.75238095          [passed: False]
# (abs distance)     density: 0.06666667                        [passed: False]
#
# graph #3
# (KS test p-value)  degree_centrality: 0.02585627              [passed: False]
# (KS test p-value)  closeness_centrality: 0.00000006           [passed: False]
# (KS test p-value)  betweenness_centrality: 0.00020212         [passed: False]
# (KS test p-value)  pagerank: 0.00061578                       [passed: False]
# (abs distance)     average_shortest_path_length: None         [passed: None]
# (abs distance)     diameter: None                             [passed: None]
# (abs distance)     degree_centralization: 0.73333333          [passed: False]
# (abs distance)     density: 0.03333333                        [passed: True]
#
# barabasi albert
# graph #1
# (KS test p-value)  degree_centrality: 0.99696924              [passed: True]
# (KS test p-value)  closeness_centrality: 0.00174595           [passed: False]
# (KS test p-value)  betweenness_centrality: 0.93600859         [passed: True]
# (KS test p-value)  pagerank: 0.53719954                       [passed: True]
# (abs distance)     average_shortest_path_length: 0.30311419   [passed: False]
# (abs distance)     diameter: 0.83333333                       [passed: False]
# (abs distance)     degree_centralization: 0.00413223          [passed: True]
# (abs distance)     density: 0.03448276                        [passed: True]
#
# graph #2
# (KS test p-value)  degree_centrality: 0.34203418              [passed: True]
# (KS test p-value)  closeness_centrality: 0.34203418           [passed: True]
# (KS test p-value)  betweenness_centrality: 0.02585627         [passed: False]
# (KS test p-value)  pagerank: 0.34203418                       [passed: True]
# (abs distance)     average_shortest_path_length: 0.07403751   [passed: False]
# (abs distance)     diameter: 0.00000000                       [passed: True]
# (abs distance)     degree_centralization: 0.09982014          [passed: False]
# (abs distance)     density: 0.05357143                        [passed: False]
#
# graph #3
# (KS test p-value)  degree_centrality: 0.53719954              [passed: True]
# (KS test p-value)  closeness_centrality: 0.34203418           [passed: True]
# (KS test p-value)  betweenness_centrality: 0.34203418         [passed: True]
# (KS test p-value)  pagerank: 0.76004651                       [passed: True]
# (abs distance)     average_shortest_path_length: 0.04166667   [passed: True]
# (abs distance)     diameter: 0.00000000                       [passed: True]
# (abs distance)     degree_centralization: 0.36250000          [passed: False]
# (abs distance)     density: 0.10400000                        [passed: False]
