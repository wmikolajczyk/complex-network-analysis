# %%
from real_graph import get_available_datasets, download_dataset, extract_dataset, count_attributes

# %%
available_datasets = get_available_datasets()
dataset_name = 'moreno_seventh'
archive_filepath = download_dataset(dataset_name, available_datasets)
# Out:
# Skipping moreno_seventh - already exists

# %%
network_filepath = extract_dataset(dataset_name, archive_filepath)
# Out:
# Skipping moreno_seventh - already exists

# %%
count_attributes(network_filepath)
# Out:
# 1

# %%
result_dict = {}
for dataset_name in available_datasets:
    archive_filepath = download_dataset(dataset_name, available_datasets)
    if archive_filepath:
        network_filepath = extract_dataset(dataset_name, archive_filepath)
        num_of_attrs = count_attributes(network_filepath)
        result_dict[dataset_name] = num_of_attrs
        print('{} :{}'.format(dataset_name, num_of_attrs))
# Out:
# Skipping actor-collaboration - already exists
# Skipping actor-collaboration - already exists
# actor-collaboration :0
# Skipping actor-movie - already exists
# Skipping actor-movie - already exists
# actor-movie :0
# Skipping adjnoun_adjacency - already exists
# Skipping adjnoun_adjacency - already exists
# adjnoun_adjacency :1
# Skipping advogato - already exists
# Skipping advogato - already exists
# advogato :1
# Skipping amazon0601 - already exists
# Skipping amazon0601 - already exists
# amazon0601 :0
# Skipping amazon-ratings - already exists
# Skipping amazon-ratings - already exists
# amazon-ratings :0
# Skipping arenas-email - already exists
# Skipping arenas-email - already exists
# arenas-email :0
# Skipping arenas-jazz - already exists
# Skipping arenas-jazz - already exists
# arenas-jazz :0
# Skipping arenas-meta - already exists
# Skipping arenas-meta - already exists
# arenas-meta :0
# Skipping arenas-pgp - already exists
# Skipping arenas-pgp - already exists
# arenas-pgp :0
# Skipping as20000102 - already exists
# Skipping as20000102 - already exists
# as20000102 :0
# Skipping as-caida20071105 - already exists
# Skipping as-caida20071105 - already exists
# as-caida20071105 :0
# Skipping as-skitter - already exists
# Skipping as-skitter - already exists
# as-skitter :0
# Skipping bibsonomy-2ti - already exists
# Skipping bibsonomy-2ti - already exists
# bibsonomy-2ti :2
# Skipping bibsonomy-2ui - already exists
# Skipping bibsonomy-2ui - already exists
# bibsonomy-2ui :1
# Skipping bibsonomy-2ut - already exists
# Skipping bibsonomy-2ut - already exists
# bibsonomy-2ut :1
# Skipping bookcrossing_full-rating - already exists
# Skipping bookcrossing_full-rating - already exists
# bookcrossing_full-rating :0
# Skipping bookcrossing_rating - already exists
# Skipping bookcrossing_rating - already exists
# bookcrossing_rating :0
# Skipping brunson_club-membership - already exists
# Skipping brunson_club-membership - already exists
# brunson_club-membership :0
# Skipping brunson_southern-women - already exists
# Skipping brunson_southern-women - already exists
# brunson_southern-women :0
# Skipping brunson_corporate-leadership - already exists
# Skipping brunson_corporate-leadership - already exists
# brunson_corporate-leadership :0
# Skipping brunson_revolution - already exists
# Skipping brunson_revolution - already exists
# brunson_revolution :0
# Skipping brunson_south-africa - already exists
# Skipping brunson_south-africa - already exists
# brunson_south-africa :0
# Skipping ca-AstroPh - already exists
# Skipping ca-AstroPh - already exists
# ca-AstroPh :0
# Skipping ca-cit-HepPh - already exists
# Skipping ca-cit-HepPh - already exists
# ca-cit-HepPh :0
# Skipping ca-cit-HepTh - already exists
# Skipping ca-cit-HepTh - already exists
# ca-cit-HepTh :0
# Skipping chess - already exists
# Skipping chess - already exists
# chess :0
# Skipping cfinder-google - already exists
# Skipping cfinder-google - already exists
# cfinder-google :1
# Skipping citeseer - already exists
# Skipping citeseer - already exists
# citeseer :0
# Skipping citeulike-ti - already exists
# Skipping citeulike-ti - already exists
# citeulike-ti :0
# Skipping citeulike-ui - already exists
# Skipping citeulike-ui - already exists
# citeulike-ui :0
# Skipping citeulike-ut - already exists
# Skipping citeulike-ut - already exists
# citeulike-ut :0
# Skipping cit-HepPh - already exists
# Skipping cit-HepPh - already exists
# cit-HepPh :0
# Skipping cit-HepTh - already exists
# Skipping cit-HepTh - already exists
# cit-HepTh :0
# Skipping com-amazon - already exists
# Skipping com-amazon - already exists
# com-amazon :0
# Skipping com-dblp - already exists
# Skipping com-dblp - already exists
# com-dblp :0
# Skipping com-youtube - already exists
# Skipping com-youtube - already exists
# com-youtube :0
# Skipping contact - already exists
# Skipping contact - already exists
# contact :0
# Skipping contiguous-usa - already exists
# Skipping contiguous-usa - already exists
# contiguous-usa :0
# Skipping dblp-author - already exists
# Skipping dblp-author - already exists
# dblp-author :0
# Skipping dblp-cite - already exists
# Skipping dblp-cite - already exists
# dblp-cite :0
# Skipping dblp_coauthor - already exists
# Skipping dblp_coauthor - already exists
# dblp_coauthor :1
# Skipping dbpedia-all - already exists
# Skipping dbpedia-all - already exists
# dbpedia-all :0
# Skipping dbpedia-country - already exists
# Skipping dbpedia-country - already exists
# dbpedia-country :0
# Skipping dbpedia-genre - already exists
# Skipping dbpedia-genre - already exists
# dbpedia-genre :0
# dbpedia-link :0
# dbpedia-location :0
# dbpedia-occupation :0
# dbpedia-producer :0
# dbpedia-recordlabel :0
# dbpedia-starring :0
# dbpedia-team :0
# dbpedia-writer :0
# dbtropes-feature :0
# Skipping delicious-ti - larger than 1000000000b
# Skipping delicious-ui - larger than 1000000000b
# Skipping delicious-ut - larger than 1000000000b
# digg-friends :0
# digg-votes :0
# discogs_affiliation :2
# discogs_genre :2
# discogs_lgenre :2
# discogs_lstyle :2
# discogs_style :2
# dnc-corecipient :0
# dnc-temporalGraph :0
# dolphins :0
# douban :0
# eat :0
# edit-dewiki :0
# edit-dewiktionary :0
# edit-enwikibooks :0
# Skipping edit-enwiki - larger than 1000000000b
# edit-enwikinews :0
# edit-enwikiquote :0
# edit-enwiktionary :0
# edit-eswiki :0
# edit-frwikibooks :0
# edit-frwiki :0
# edit-frwikinews :0
# edit-frwiktionary :0
# edit-itwiki :0
# ego-facebook :0
# ego-gplus :0
# ego-twitter :0
# elec :0
# email-EuAll :0
# enron :0
# epinions :0
# epinions-rating :0
# escorts :0
# facebook-wosn-links :0
# facebook-wosn-wall :0
# flickrEdges :0
# flickr-groupmemberships :0
# flickr-growth :0
# flickr-links :0
# flixster :0
# foldoc :0
# foodweb-baydry :0
# foodweb-baywet :0
# Skipping friendster - larger than 1000000000b
# github :2
# gottron-excellent :0
# gottron-reuters :0
